# %%
def find_password(input_text):

    with open(input_text) as f:
        data = f.read().splitlines()
        
        pointing = 50
        count = 0
        for i in data:
            if i[0] == 'L':
                pointing = (pointing - int(i[1:])) % 100
            elif i[0] == 'R':
                pointing = (pointing + int(i[1:])) % 100

            if pointing == 0:
                count += 1
    
        return count

find_password(input_text='input.txt')
# Out:
# 1076
